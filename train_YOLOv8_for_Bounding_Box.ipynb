# %% [markdown]
# <a href="https://colab.research.google.com/github/aycaaozturk/Nail-Melanoma-Project/blob/main/train_YOLOv8_for_Bounding_Box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip list | grep torch
# Out:
# torch                                    2.8.0+cu126
# torchao                                  0.10.0
# torchaudio                               2.8.0+cu126
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.23.0+cu126

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 39.1/235.7 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Below is the path to the dataset.
# Dataset should be in yolov8 format.
# The dataset used in this experiment was labeled, augmented and exported via Roboflow (online platform to work with datasets)
# On the right are the hyperparameters to experiment with.

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=20 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
